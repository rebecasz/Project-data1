# %%
import pandas as pd

# Define the data as a list of dictionaries
data = [
    {'CustomerID': 1001, 'Date': '2023-01-01', 'ProductID': 101, 'ProductName': 'Laptop', 'Category': 'Electronics', 'Price': 800, 'Quantity': 1, 'TotalPrice': 800, 'Country': 'USA'},
    {'CustomerID': 1002, 'Date': '2023-01-01', 'ProductID': 102, 'ProductName': 'T-shirt', 'Category': 'Clothing', 'Price': 20, 'Quantity': 2, 'TotalPrice': 40, 'Country': 'USA'},
    {'CustomerID': 1003, 'Date': '2023-01-02', 'ProductID': 103, 'ProductName': 'Smartphone', 'Category': 'Electronics', 'Price': 600, 'Quantity': 1, 'TotalPrice': 600, 'Country': 'UK'},
    {'CustomerID': 1004, 'Date': '2023-01-02', 'ProductID': 104, 'ProductName': 'Headphones', 'Category': 'Electronics', 'Price': 50, 'Quantity': 1, 'TotalPrice': 50, 'Country': 'Germany'},
    {'CustomerID': 1005, 'Date': '2023-01-03', 'ProductID': 105, 'ProductName': 'Coffee Table', 'Category': 'Home Decor', 'Price': 200, 'Quantity': 1, 'TotalPrice': 200, 'Country': 'France'},
    {'CustomerID': 1006, 'Date': '2023-01-03', 'ProductID': 106, 'ProductName': 'Jeans', 'Category': 'Clothing', 'Price': 50, 'Quantity': 1, 'TotalPrice': 50, 'Country': 'USA'},
    {'CustomerID': 1007, 'Date': '2023-01-04', 'ProductID': 107, 'ProductName': 'Smartwatch', 'Category': 'Electronics', 'Price': 300, 'Quantity': 1, 'TotalPrice': 300, 'Country': 'Canada'},
    {'CustomerID': 1008, 'Date': '2023-01-04', 'ProductID': 108, 'ProductName': 'Dress', 'Category': 'Clothing', 'Price': 40, 'Quantity': 1, 'TotalPrice': 40, 'Country': 'USA'},
    {'CustomerID': 1009, 'Date': '2023-01-05', 'ProductID': 109, 'ProductName': 'Camera', 'Category': 'Electronics', 'Price': 400, 'Quantity': 1, 'TotalPrice': 400, 'Country': 'UK'},
    {'CustomerID': 1010, 'Date': '2023-01-05', 'ProductID': 110, 'ProductName': 'Desk Lamp', 'Category': 'Home Decor', 'Price': 30, 'Quantity': 1, 'TotalPrice': 30, 'Country': 'France'},
    {'CustomerID': 1011, 'Date': '2023-01-06', 'ProductID': 111, 'ProductName': 'Sneakers', 'Category': 'Clothing', 'Price': 80, 'Quantity': 1, 'TotalPrice': 80, 'Country': 'USA'},
    {'CustomerID': 1012, 'Date': '2023-01-06', 'ProductID': 112, 'ProductName': 'Tablet', 'Category': 'Electronics', 'Price': 250, 'Quantity': 1, 'TotalPrice': 250, 'Country': 'Germany'},
    {'CustomerID': 1013, 'Date': '2023-01-07', 'ProductID': 113, 'ProductName': 'Sofa', 'Category': 'Home Decor', 'Price': 700, 'Quantity': 1, 'TotalPrice': 700, 'Country': 'Canada'},
    {'CustomerID': 1014, 'Date': '2023-01-07', 'ProductID': 114, 'ProductName': 'Jacket', 'Category': 'Clothing', 'Price': 60, 'Quantity': 1, 'TotalPrice': 60, 'Country': 'USA'},
    {'CustomerID': 1015, 'Date': '2023-01-08', 'ProductID': 115, 'ProductName': 'Watch', 'Category': 'Accessories', 'Price': 150, 'Quantity': 1, 'TotalPrice': 150, 'Country': 'UK'},
    {'CustomerID': 1016, 'Date': '2023-01-08', 'ProductID': 116, 'ProductName': 'Bed Frame', 'Category': 'Furniture', 'Price': 800, 'Quantity': 1, 'TotalPrice': 800, 'Country': 'France'},
    {'CustomerID': 1017, 'Date': '2023-01-09', 'ProductID': 117, 'ProductName': 'Backpack', 'Category': 'Accessories', 'Price': 50, 'Quantity': 1, 'TotalPrice': 50, 'Country': 'Germany'},
    {'CustomerID': 1018, 'Date': '2023-01-09', 'ProductID': 118, 'ProductName': 'Bookshelf', 'Category': 'Furniture', 'Price': 120, 'Quantity': 1, 'TotalPrice': 120, 'Country': 'USA'},
    {'CustomerID': 1019, 'Date': '2023-01-10', 'ProductID': 119, 'ProductName': 'Bluetooth Speaker', 'Category': 'Electronics', 'Price': 100, 'Quantity': 1, 'TotalPrice': 100, 'Country': 'Canada'},
    {'CustomerID': 1020, 'Date': '2023-01-10', 'ProductID': 120, 'ProductName': 'Hoodie', 'Category': 'Clothing', 'Price': 40, 'Quantity': 1, 'TotalPrice': 40, 'Country': 'UK'},
    {'CustomerID': 1021, 'Date': '2023-01-11', 'ProductID': 121, 'ProductName': 'Gaming Console', 'Category': 'Electronics', 'Price': 400, 'Quantity': 1, 'TotalPrice': 400, 'Country': 'USA'},
    {'CustomerID': 1022, 'Date': '2023-01-11', 'ProductID': 122, 'ProductName': 'Sunglasses', 'Category': 'Accessories', 'Price': 80, 'Quantity': 1, 'TotalPrice': 80, 'Country': 'Germany'},
    {'CustomerID': 1023, 'Date': '2023-01-12', 'ProductID': 123, 'ProductName': 'Office Chair', 'Category': 'Furniture', 'Price': 150, 'Quantity': 1, 'TotalPrice': 150, 'Country': 'UK'},
    {'CustomerID': 1024, 'Date': '2023-01-12', 'ProductID': 124, 'ProductName': 'Running Shoes', 'Category': 'Clothing', 'Price': 90, 'Quantity': 1, 'TotalPrice': 90, 'Country': 'France'},
    {'CustomerID': 1025, 'Date': '2023-01-13', 'ProductID': 125, 'ProductName': 'Wireless Mouse', 'Category': 'Electronics', 'Price': 20, 'Quantity': 1, 'TotalPrice': 20, 'Country': 'Canada'},
    {'CustomerID': 1026, 'Date': '2023-01-13', 'ProductID': 126, 'ProductName': 'Scarf', 'Category': 'Accessories', 'Price': 25, 'Quantity': 1, 'TotalPrice': 25, 'Country': 'USA'},
    {'CustomerID': 1027, 'Date': '2023-01-14', 'ProductID': 127, 'ProductName': 'Home Theater System', 'Category': 'Electronics', 'Price': 600, 'Quantity': 1, 'TotalPrice': 600, 'Country': 'Germany'},
    {'CustomerID': 1028, 'Date': '2023-01-14', 'ProductID': 128, 'ProductName': 'Yoga Mat', 'Category': 'Sports', 'Price': 35, 'Quantity': 1, 'TotalPrice': 35, 'Country': 'UK'},
    {'CustomerID': 1029, 'Date': '2023-01-15', 'ProductID': 129, 'ProductName': 'Gaming Mouse', 'Category': 'Electronics', 'Price': 50, 'Quantity': 1, 'TotalPrice': 50, 'Country': 'France'},
    {'CustomerID': 1030, 'Date': '2023-01-15', 'ProductID': 130, 'ProductName': 'Kitchen Knife Set', 'Category': 'Kitchenware', 'Price': 60, 'Quantity': 1, 'TotalPrice': 60, 'Country': 'USA'},
    {'CustomerID': 1031, 'Date': '2023-01-16', 'ProductID': 131, 'ProductName': 'Speaker System', 'Category': 'Electronics', 'Price': 120, 'Quantity': 1, 'TotalPrice': 120, 'Country': 'Canada'},
    {'CustomerID': 1032, 'Date': '2023-01-16', 'ProductID': 132, 'ProductName': 'Watch', 'Category': 'Accessories', 'Price': 200, 'Quantity': 1, 'TotalPrice': 200, 'Country': 'UK'},
    {'CustomerID': 1033, 'Date': '2023-01-17', 'ProductID': 133, 'ProductName': 'Running Shorts', 'Category': 'Clothing', 'Price': 30, 'Quantity': 1, 'TotalPrice': 30, 'Country': 'Germany'},
    {'CustomerID': 1034, 'Date': '2023-01-17', 'ProductID': 134, 'ProductName': 'Blender', 'Category': 'Kitchenware', 'Price': 80, 'Quantity': 1, 'TotalPrice': 80, 'Country': 'USA'},
    {'CustomerID': 1035, 'Date': '2023-01-18', 'ProductID': 135, 'ProductName': 'Wireless Headphones', 'Category': 'Electronics', 'Price': 70, 'Quantity': 1, 'TotalPrice': 70, 'Country': 'Canada'},
    {'CustomerID': 1036, 'Date': '2023-01-18', 'ProductID': 136, 'ProductName': 'Candle Holder', 'Category': 'Home Decor', 'Price': 40, 'Quantity': 1, 'TotalPrice': 40, 'Country': 'UK'},
    {'CustomerID': 1037, 'Date': '2023-01-19', 'ProductID': 137, 'ProductName': 'Desk Lamp', 'Category': 'Home Decor', 'Price': 150, 'Quantity': 1, 'TotalPrice': 150, 'Country': 'USA'},
    {'CustomerID': 1038, 'Date': '2023-01-19', 'ProductID': 138, 'ProductName': 'Smart Home Device', 'Category': 'Electronics', 'Price': 25, 'Quantity': 1, 'TotalPrice': 25, 'Country': 'Germany'},
    {'CustomerID': 1039, 'Date': '2023-01-20', 'ProductID': 139, 'ProductName': 'Cookware Set', 'Category': 'Kitchenware', 'Price': 150, 'Quantity': 1, 'TotalPrice': 150, 'Country': 'Germany'},
    {'CustomerID': 1040, 'Date': '2023-01-20', 'ProductID': 140, 'ProductName': 'Laptop Stand', 'Category': 'Electronics', 'Price': 25, 'Quantity': 1, 'TotalPrice': 25, 'Country': 'UK'},
    {'CustomerID': 1041, 'Date': '2023-01-21', 'ProductID': 141, 'ProductName': 'Wireless Charger', 'Category': 'Accessories', 'Price': 30, 'Quantity': 1, 'TotalPrice': 30, 'Country': 'France'},
    {'CustomerID': 1042, 'Date': '2023-01-21', 'ProductID': 142, 'ProductName': 'Tote Bag', 'Category': 'Accessories', 'Price': 45, 'Quantity': 1, 'TotalPrice': 45, 'Country': 'Canada'},
    {'CustomerID': 1043, 'Date': '2023-01-22', 'ProductID': 143, 'ProductName': 'Vacuum Cleaner', 'Category': 'Home', 'Price': 200, 'Quantity': 1, 'TotalPrice': 200, 'Country': 'USA'},
    {'CustomerID': 1044, 'Date': '2023-01-22', 'ProductID': 144, 'ProductName': 'Water Bottle', 'Category': 'Accessories', 'Price': 15, 'Quantity': 1, 'TotalPrice': 15, 'Country': 'UK'},
    {'CustomerID': 1045, 'Date': '2023-01-23', 'ProductID': 145, 'ProductName': 'Desk Organizer', 'Category': 'Office', 'Price': 20, 'Quantity': 1, 'TotalPrice': 20, 'Country': 'Germany'},
    {'CustomerID': 1046, 'Date': '2023-01-23', 'ProductID': 146, 'ProductName': 'Hair Dryer', 'Category': 'Personal Care', 'Price': 40, 'Quantity': 1, 'TotalPrice': 40, 'Country': 'France'},
    {'CustomerID': 1047, 'Date': '2023-01-24', 'ProductID': 147, 'ProductName': 'Gaming Keyboard', 'Category': 'Electronics', 'Price': 80, 'Quantity': 1, 'TotalPrice': 80, 'Country': 'Canada'},
    {'CustomerID': 1048, 'Date': '2023-01-24', 'ProductID': 148, 'ProductName': 'Sunglasses', 'Category': 'Accessories', 'Price': 70, 'Quantity': 1, 'TotalPrice': 70, 'Country': 'USA'},
    {'CustomerID': 1049, 'Date': '2023-01-25', 'ProductID': 149, 'ProductName': 'Home Decorations', 'Category': 'Home Decor', 'Price': 50, 'Quantity': 1, 'TotalPrice': 50, 'Country': 'UK'},
    {'CustomerID': 1050, 'Date': '2023-01-25', 'ProductID': 150, 'ProductName': 'Portable Speaker', 'Category': 'Electronics', 'Price': 100, 'Quantity': 1, 'TotalPrice': 100, 'Country': 'France'}
]

# Create a DataFrame
df = pd.DataFrame(data)

# Save DataFrame to CSV file
df.to_csv('ecommerce_sales_data.csv', index=False)
